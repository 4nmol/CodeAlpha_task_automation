# %%
pip install schedule
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting schedule
#   Using cached schedule-1.2.2-py3-none-any.whl.metadata (3.8 kB)
# Using cached schedule-1.2.2-py3-none-any.whl (12 kB)
# Installing collected packages: schedule
# Successfully installed schedule-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import schedule  #importing scedule library

# %%
import pandas as pd #importing panda library

# %%
import time #importing time library

# %%
# Function for data cleaning using python task internship at code alpha
def clean_data():
    # For loading the data from CSV
    df = pd.read_csv('dataset1.csv')
    print(df)
    
clean_data()
# Out:
#      country  age    salary purchased
# 0     india   18.0  10000.0       yes
# 1     india   19.0  20000.0        no
# 2     china   20.0  30000.0       yes
# 3     china   21.0  40000.0       yes
# 4    france   22.0  50000.0        no
# 5   veitnam   23.0  60000.0        no
# 6   thialand  24.0  20000.0       yes
# 7  thiailand  19.0      NaN       NaN
# 8    vietnam   NaN  30000.0        no
# 9      inida   NaN     28.0       NaN

# %%
df = pd.read_csv('dataset1.csv')
df
# Out:
#      country  age    salary purchased
# 0     india   18.0  10000.0       yes
# 1     india   19.0  20000.0        no
# 2     china   20.0  30000.0       yes
# 3     china   21.0  40000.0       yes
# 4    france   22.0  50000.0        no
# 5   veitnam   23.0  60000.0        no
# 6   thialand  24.0  20000.0       yes
# 7  thiailand  19.0      NaN       NaN
# 8    vietnam   NaN  30000.0        no
# 9      inida   NaN     28.0       NaN

# %%
# Function for data cleaning using python task internship at code alpha
def clean_data():
    # For loading the data from CSV
    df = pd.read_csv('dataset1.csv')
    
    # filling missing values with 0 zero
    df.fillna(0, inplace=True)
    print(df)


clean_data()
# Out:
#      country  age    salary purchased
# 0     india   18.0  10000.0       yes
# 1     india   19.0  20000.0        no
# 2     china   20.0  30000.0       yes
# 3     china   21.0  40000.0       yes
# 4    france   22.0  50000.0        no
# 5   veitnam   23.0  60000.0        no
# 6   thialand  24.0  20000.0       yes
# 7  thiailand  19.0      0.0         0
# 8    vietnam   0.0  30000.0        no
# 9      inida   0.0     28.0         0

# %%
# Function for data cleaning using python task internship at code alpha
def clean_data():
    # For loading the data from CSV
    df = pd.read_csv('dataset1.csv')
    
    # filling missing values with 0 zero
    df.fillna(0, inplace=True)

     # Removing duplicate values
    df.drop_duplicates(inplace=True)
    
    print(df)
clean_data()
# Out:
#      country  age    salary purchased
# 0     india   18.0  10000.0       yes
# 1     india   19.0  20000.0        no
# 2     china   20.0  30000.0       yes
# 3     china   21.0  40000.0       yes
# 4    france   22.0  50000.0        no
# 5   veitnam   23.0  60000.0        no
# 6   thialand  24.0  20000.0       yes
# 7  thiailand  19.0      0.0         0
# 8    vietnam   0.0  30000.0        no
# 9      inida   0.0     28.0         0

# %%
def clean_data():
    # For loading the data from CSV
    df = pd.read_csv('dataset1.csv')
    
    # filling missing values with 0 zero
    df.fillna(0, inplace=True)

     # Removing duplicate values
    df.drop_duplicates(inplace=True)

     # Trimming whitespaces and coverting uppercase to lower case in country column
    if 'country' in df.columns:
        df['country'] = df['country'].str.strip().str.lower()
    
    print(df)
    
clean_data()
# Out:
#      country  age    salary purchased
# 0      india  18.0  10000.0       yes
# 1      india  19.0  20000.0        no
# 2      china  20.0  30000.0       yes
# 3      china  21.0  40000.0       yes
# 4     france  22.0  50000.0        no
# 5    veitnam  23.0  60000.0        no
# 6   thialand  24.0  20000.0       yes
# 7  thiailand  19.0      0.0         0
# 8    vietnam   0.0  30000.0        no
# 9      inida   0.0     28.0         0

# %%
def clean_data():
    # For loading the data from CSV
    df = pd.read_csv('dataset1.csv')
    
    # filling missing values with 0 zero
    df.fillna(0, inplace=True)

     # Removing duplicate values
    df.drop_duplicates(inplace=True)

     # Trimming whitespaces and coverting uppercase to lower case in country column
    if 'country' in df.columns:
        df['country'] = df['country'].str.strip().str.lower()

    # Saving cleaned data to a new CSV
    df.to_csv('cleaned_data.csv', index=False)
    print("Data cleaning completed and saved.")

    # Schedule the task to run every day at 10:00 AM
    schedule.every().day.at("11:51").do(clean_data)

    
    
    print(df)
    
clean_data()
# Out:
# Data cleaning completed and saved.
#      country  age    salary purchased
# 0      india  18.0  10000.0       yes
# 1      india  19.0  20000.0        no
# 2      china  20.0  30000.0       yes
# 3      china  21.0  40000.0       yes
# 4     france  22.0  50000.0        no
# 5    veitnam  23.0  60000.0        no
# 6   thialand  24.0  20000.0       yes
# 7  thiailand  19.0      0.0         0
# 8    vietnam   0.0  30000.0        no
# 9      inida   0.0     28.0         0

# %%
def clean_data():
    # For loading the data from CSV
    df = pd.read_csv('dataset1.csv')
    
    # filling missing values with 0 zero
    df.fillna(0, inplace=True)

     # Removing duplicate values
    df.drop_duplicates(inplace=True)

     # Trimming whitespaces and coverting uppercase to lower case in country column
    if 'country' in df.columns:
        df['country'] = df['country'].str.strip().str.lower()

    # Saving cleaned data to a new CSV
    df.to_csv('cleaned_data.csv', index=False)
    print("Data cleaning completed and saved.")

    # Scheduling  the task to run every day at 10:53 AM
    schedule.every().day.at("10:53").do(clean_data)

    while True:
        schedule.run_pending()
        time.sleep(1)
    
    print(df)
    
clean_data()
# Out:
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# Data cleaning completed and saved.
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[39], line 28
#      24         time.sleep(1)
#      26     print(df)
# ---> 28 clean_data()
#
# Cell In[39], line 23, in clean_data()
#      20 schedule.every().day.at("10:53").do(clean_data)
#      22 while True:
# ---> 23     schedule.run_pending()
#      24     time.sleep(1)
#      26 print(df)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:854, in run_pending()
#     850 def run_pending() -> None:
#     851     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     852     :data:`default scheduler instance <default_scheduler>`.
#     853     """
# --> 854     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:101, in Scheduler.run_pending(self)
#      99 runnable_jobs = (job for job in self.jobs if job.should_run)
#     100 for job in sorted(runnable_jobs):
# --> 101     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:173, in Scheduler._run_job(self, job)
#     172 def _run_job(self, job: "Job") -> None:
# --> 173     ret = job.run()
#     174     if isinstance(ret, CancelJob) or ret is CancelJob:
#     175         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:691, in Job.run(self)
#     688     return CancelJob
#     690 logger.debug("Running job %s", self)
# --> 691 ret = self.job_func()
#     692 self.last_run = datetime.datetime.now()
#     693 self._schedule_next_run()
#
# Cell In[38], line 23, in clean_data()
#      20 schedule.every().day.at("11:53").do(clean_data)
#      22 while True:
# ---> 23     schedule.run_pending()
#      24     time.sleep(1)
#      26 print(df)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:854, in run_pending()
#     850 def run_pending() -> None:
#     851     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     852     :data:`default scheduler instance <default_scheduler>`.
#     853     """
# --> 854     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:101, in Scheduler.run_pending(self)
#      99 runnable_jobs = (job for job in self.jobs if job.should_run)
#     100 for job in sorted(runnable_jobs):
# --> 101     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:173, in Scheduler._run_job(self, job)
#     172 def _run_job(self, job: "Job") -> None:
# --> 173     ret = job.run()
#     174     if isinstance(ret, CancelJob) or ret is CancelJob:
#     175         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:691, in Job.run(self)
#     688     return CancelJob
#     690 logger.debug("Running job %s", self)
# --> 691 ret = self.job_func()
#     692 self.last_run = datetime.datetime.now()
#     693 self._schedule_next_run()
#
# Cell In[38], line 23, in clean_data()
#      20 schedule.every().day.at("11:53").do(clean_data)
#      22 while True:
# ---> 23     schedule.run_pending()
#      24     time.sleep(1)
#      26 print(df)
#
#     [... skipping similar frames: Scheduler._run_job at line 173 (590 times), Job.run at line 691 (590 times), run_pending at line 854 (590 times), Scheduler.run_pending at line 101 (590 times), clean_data at line 23 (589 times)]
#
# Cell In[38], line 23, in clean_data()
#      20 schedule.every().day.at("11:53").do(clean_data)
#      22 while True:
# ---> 23     schedule.run_pending()
#      24     time.sleep(1)
#      26 print(df)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:854, in run_pending()
#     850 def run_pending() -> None:
#     851     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     852     :data:`default scheduler instance <default_scheduler>`.
#     853     """
# --> 854     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:101, in Scheduler.run_pending(self)
#      99 runnable_jobs = (job for job in self.jobs if job.should_run)
#     100 for job in sorted(runnable_jobs):
# --> 101     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:173, in Scheduler._run_job(self, job)
#     172 def _run_job(self, job: "Job") -> None:
# --> 173     ret = job.run()
#     174     if isinstance(ret, CancelJob) or ret is CancelJob:
#     175         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\schedule\__init__.py:691, in Job.run(self)
#     688     return CancelJob
#     690 logger.debug("Running job %s", self)
# --> 691 ret = self.job_func()
#     692 self.last_run = datetime.datetime.now()
#     693 self._schedule_next_run()
#
# Cell In[38], line 3, in clean_data()
#       1 def clean_data():
#       2     # For loading the data from CSV
# ----> 3     df = pd.read_csv('dataset1.csv')
#       5     # filling missing values with 0 zero
#       6     df.fillna(0, inplace=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1968, in TextFileReader.read(self, nrows)
#    1965     else:
#    1966         new_col_dict = col_dict
# -> 1968     df = DataFrame(
#    1969         new_col_dict,
#    1970         columns=columns,
#    1971         index=index,
#    1972         copy=not using_copy_on_write(),
#    1973     )
#    1975     self._currow += new_rows
#    1976 return df
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:443, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     440 if columns is not None:
#     441     from pandas.core.series import Series
# --> 443     arrays = Series(data, index=columns, dtype=object)
#     444     missing = arrays.isna()
#     445     if index is None:
#     446         # GH10856
#     447         # raise ValueError if only scalars in dict
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:490, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     487 name = ibase.maybe_extract_name(name, data, type(self))
#     489 if index is not None:
# --> 490     index = ensure_index(index)
#     492 if dtype is not None:
#     493     dtype = self._validate_dtype(dtype)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7647, in ensure_index(index_like, copy)
#    7645         return MultiIndex.from_arrays(index_like)
#    7646     else:
# -> 7647         return Index(index_like, copy=copy, tupleize_cols=False)
#    7648 else:
#    7649     return Index(index_like, copy=copy)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:565, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     562         data = com.asarray_tuplesafe(data, dtype=_dtype_obj)
#     564 try:
# --> 565     arr = sanitize_array(data, None, dtype=dtype, copy=copy)
#     566 except ValueError as err:
#     567     if "index must be specified when data is not list-like" in str(err):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\construction.py:654, in sanitize_array(data, index, dtype, copy, allow_2d)
#     651     subarr = _try_cast(data, dtype, copy)
#     653 else:
# --> 654     subarr = maybe_convert_platform(data)
#     655     if subarr.dtype == object:
#     656         subarr = cast(np.ndarray, subarr)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:139, in maybe_convert_platform(values)
#     137 if arr.dtype == _dtype_obj:
#     138     arr = cast(np.ndarray, arr)
# --> 139     arr = lib.maybe_convert_objects(arr)
#     141 return arr
#
# File lib.pyx:2543, in pandas._libs.lib.maybe_convert_objects()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\core\numeric.py:330, in full(shape, fill_value, dtype, order, like)
#     328     dtype = fill_value.dtype
#     329 a = empty(shape, dtype, order)
# --> 330 multiarray.copyto(a, fill_value, casting='unsafe')
#     331 return a
#
# RecursionError: maximum recursion depth exceeded
